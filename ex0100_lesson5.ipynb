# %%
import datetime
today=datetime.date.today()
print(f"HELLO {today}'s world!")
# Out:
# HELLO 2023-07-08's world!

# %%
#Range的三種引述
for i in range(7):
    print(f'1種的{i}')

for i in range(3,15):
    print(f'2種的{i}')
    
for i in range(1,50,3):
    print(f'3種的{i}')
# Out:
# 1種的0
# 1種的1
# 1種的2
# 1種的3
# 1種的4
# 1種的5
# 1種的6
# 2種的3
# 2種的4
# 2種的5
# 2種的6
# 2種的7
# 2種的8
# 2種的9
# 2種的10
# 2種的11
# 2種的12
# 2種的13
# 2種的14
# 3種的1
# 3種的4
# 3種的7
# 3種的10
# 3種的13
# 3種的16
# 3種的19
# 3種的22
# 3種的25
# 3種的28
# 3種的31
# 3種的34
# 3種的37
# 3種的40
# 3種的43
# 3種的46
# 3種的49

# %%
j=0
for i in range(1,10):
    print (f"i={i}")
    for j in range(1,20,2):
        print(f"j={j}")
    print("=======================")
# Out:
# i=1
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...
# i=2
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...
# i=3
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...
# i=4
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...
# i=5
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...
# i=6
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...
# i=7
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...
# i=8
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...
# i=9
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# ...

# %%
for i in range(1,10):
    print (f"i={i}->")
    for j in range(1,20,2):
        print(f"j={j}",end=" ")
    print("\n=======================")
# Out:
# i=1->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...
# i=2->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...
# i=3->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...
# i=4->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...
# i=5->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...
# i=6->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...
# i=7->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...
# i=8->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...
# i=9->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# ...

# %%
#改成九九乘法表

for i in range(1,10):
    print (f"i={i}=======")
    for j in range(1,10):
        print(f"{i}x{j}={i*j}")
    print("==========\n")
# Out:
# i=1=======
# 1x1=1
# 1x2=2
# 1x3=3
# 1x4=4
# 1x5=5
# 1x6=6
# 1x7=7
# 1x8=8
# 1x9=9
# ...
#
# i=2=======
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# ...
#
# i=3=======
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
# ...
#
# i=4=======
# 4x1=4
# 4x2=8
# 4x3=12
# 4x4=16
# 4x5=20
# 4x6=24
# 4x7=28
# 4x8=32
# 4x9=36
# ...
#
# i=5=======
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
# ...
#
# i=6=======
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# 6x8=48
# 6x9=54
# ...
#
# i=7=======
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
# ...
#
# i=8=======
# 8x1=8
# 8x2=16
# 8x3=24
# 8x4=32
# 8x5=40
# 8x6=48
# 8x7=56
# 8x8=64
# 8x9=72
# ...
#
# i=9=======
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81
# ...

# %%
#小明想要買一台30000元的機車
accu_deposit=0
deposit=0
month=0
while accu_deposit<=30000:
    month+=1
    deposit=int(input(f"第{month}個月的可存入:"))
    accu_deposit+=deposit
    print(f"第{month}個月的累計存款為{accu_deposit}元")

print(f"提醒! 存到第{month}月，存了{accu_deposit}元，可以買機車了")
# Out:
# 第1個月的累計存款為8897元
# 第2個月的累計存款為16884元
# 第3個月的累計存款為21530元
# 第4個月的累計存款為5486976元
# 提醒! 存到第4月，存了5486976元，可以買機車了
