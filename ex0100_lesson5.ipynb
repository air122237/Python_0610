# %%
import datetime
today=datetime.date.today()
print(f"HELLO {today}'s world!")
# Out:
# HELLO 2023-07-08's world!

# %%
#Range的三種引述
for i in range(7):
    print(f'1種的{i}')

for i in range(3,15):
    print(f'2種的{i}')
    
for i in range(1,50,3):
    print(f'3種的{i}')
# Out:
# 1種的0
# 1種的1
# 1種的2
# 1種的3
# 1種的4
# 1種的5
# 1種的6
# 2種的3
# 2種的4
# 2種的5
# 2種的6
# 2種的7
# 2種的8
# 2種的9
# 2種的10
# 2種的11
# 2種的12
# 2種的13
# 2種的14
# 3種的1
# 3種的4
# 3種的7
# 3種的10
# 3種的13
# 3種的16
# 3種的19
# 3種的22
# 3種的25
# 3種的28
# 3種的31
# 3種的34
# 3種的37
# 3種的40
# 3種的43
# 3種的46
# 3種的49

# %%
j=0
for i in range(1,10):
    print (f"i={i}")
    for j in range(1,20,2):
        print(f"j={j}")
    print("=======================")
# Out:
# i=1
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================
# i=2
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================
# i=3
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================
# i=4
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================
# i=5
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================
# i=6
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================
# i=7
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================
# i=8
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================
# i=9
# j=1
# j=3
# j=5
# j=7
# j=9
# j=11
# j=13
# j=15
# j=17
# j=19
# =======================

# %%
for i in range(1,10):
    print (f"i={i}->")
    for j in range(1,20,2):
        print(f"j={j}",end=" ")
    print("\n=======================")
# Out:
# i=1->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================
# i=2->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================
# i=3->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================
# i=4->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================
# i=5->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================
# i=6->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================
# i=7->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================
# i=8->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================
# i=9->
# j=1 j=3 j=5 j=7 j=9 j=11 j=13 j=15 j=17 j=19
# =======================

# %%
#改成九九乘法表

for i in range(1,10):
    print (f"i={i}=======")
    for j in range(1,20,2):
        print(f"{i}x{j}={i*j}")
    print("==========\n")
# Out:
# i=1=======
# 1x1=1
# 1x3=3
# 1x5=5
# 1x7=7
# 1x9=9
# 1x11=11
# 1x13=13
# 1x15=15
# 1x17=17
# 1x19=19
# ==========
#
# i=2=======
# 2x1=2
# 2x3=6
# 2x5=10
# 2x7=14
# 2x9=18
# 2x11=22
# 2x13=26
# 2x15=30
# 2x17=34
# 2x19=38
# ==========
#
# i=3=======
# 3x1=3
# 3x3=9
# 3x5=15
# 3x7=21
# 3x9=27
# 3x11=33
# 3x13=39
# 3x15=45
# 3x17=51
# 3x19=57
# ==========
#
# i=4=======
# 4x1=4
# 4x3=12
# 4x5=20
# 4x7=28
# 4x9=36
# 4x11=44
# 4x13=52
# 4x15=60
# 4x17=68
# 4x19=76
# ==========
#
# i=5=======
# 5x1=5
# 5x3=15
# 5x5=25
# 5x7=35
# 5x9=45
# 5x11=55
# 5x13=65
# 5x15=75
# 5x17=85
# 5x19=95
# ==========
#
# i=6=======
# 6x1=6
# 6x3=18
# 6x5=30
# 6x7=42
# 6x9=54
# 6x11=66
# 6x13=78
# 6x15=90
# 6x17=102
# 6x19=114
# ==========
#
# i=7=======
# 7x1=7
# 7x3=21
# 7x5=35
# 7x7=49
# 7x9=63
# 7x11=77
# 7x13=91
# 7x15=105
# 7x17=119
# 7x19=133
# ==========
#
# i=8=======
# 8x1=8
# 8x3=24
# 8x5=40
# 8x7=56
# 8x9=72
# 8x11=88
# 8x13=104
# 8x15=120
# 8x17=136
# 8x19=152
# ==========
#
# i=9=======
# 9x1=9
# 9x3=27
# 9x5=45
# 9x7=63
# 9x9=81
# 9x11=99
# 9x13=117
# 9x15=135
# 9x17=153
# 9x19=171
# ==========

# %%
#
accu_deposit=0
deposit=0
i=1
while accu_deposit<=30000:
    deposit=int(input(f"第{i}個月的存款:"))
    accu_deposit+=deposit
    print(f"第{i}個月的累計存款為{accu_deposit}")
    i+=1
print(f"提醒! 存到第{i-1}月，可以買機車了")
# Out:
# 第1個月的累計存款為5000
# 第2個月的累計存款為12000
# 第3個月的累計存款為15000
# 第4個月的累計存款為19000
# 第5個月的累計存款為27000
# 第6個月的累計存款為35000
# 提醒! 存到第6月，可以買機車了
