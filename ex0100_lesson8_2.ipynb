# %%
import csv
filename="111年-淡水區.csv"
estate_file=open(filename,mode='r',encoding="utf-8",newline='')
estate_file_lines=csv.reader(estate_file)
all_lines=list(estate_file_lines)
for item in all_lines:
    if "新市一路一段" in item[2]:
        print(item)
# Out:
# ['淡水區', '房地(土地+建物)+車位', '新北市淡水區新市一路一段５６號三樓', '19.04', '住', '', '', '1110206', '土地1建物1車位1', '三層', '二十層', '住宅大樓(11層含以上有電梯)', '住家用', '鋼筋混凝土造', '1000214', '160.36', '3', '2', '2', '有', '有', '8200000', '51135', '坡道平面', '24.57', '0', '親友、員工、共有人或其他特殊關係間之交易；', 'RPQNMLPLKHHGFEF08EA', '80.51', '9.78', '5.63', '有']
# ['淡水區', '房地(土地+建物)+車位', '新北市淡水區新市一路一段５８號二十樓', '17.33', '住', '', '', '1110103', '土地1建物1車位1', '二十層', '二十層', '住宅大樓(11層含以上有電梯)', '住家用', '鋼筋混凝土造', '1000214', '147.39', '3', '2', '2', '有', '有', '10000000', '67847', '坡道平面', '22.88', '0', '', 'RPOOMLLLJHHGFEF47EA', '73.33', '9.19', '5.63', '有']
# ['淡水區', '房地(土地+建物)+車位', '新北市淡水區新市一路一段６０號二十樓', '15.31', '住', '', '', '1110108', '土地1建物1車位1', '二十層', '二十層', '住宅大樓(11層含以上有電梯)', '住家用', '鋼筋混凝土造', '1000214', '132.81', '3', '2', '2', '有', '有', '9300000', '70025', '坡道平面', '24.56', '0', '', 'RPQNMLSLJHHGFEF28EA', '64.64', '5.96', '5.66', '有']
# ...
